# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Data file.csv',parse_dates=['pdate'],index_col=[0])
data.head()
pd.set_option('display.max_columns', None)

# %%
data.head(20)
# Out:
#     label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 1       0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 2       1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 3       1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 4       1  55773I70781   241.0     21.228000     21.228000    159.42
# 5       1  03813I82730   947.0    150.619333    150.619333   1098.90
# 6       1  35819I70783   568.0   2257.362667   2261.460000    368.13
# 7       1  96759I84459   545.0   2876.641667   2883.970000    335.75
# 8       1  09832I90846   768.0  12905.000000  17804.150000    900.35
# 9       1  59772I84450  1191.0     90.695000     90.695000   2287.50
# 10      1  56331I70783   536.0     29.357333     29.357333    612.96
# 11      1  32893I82732  1511.0     12.896000     12.896000    790.44
# 12      0  82417I90848    82.0     65.166667     65.166667    326.20
# 13      1  11435I89236   154.0    227.041000    227.041000    240.41
# ...

# %%
data.shape
# Out:
# (209593, 36)

# %%
data[data.cnt_loans90 <=0]
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 128         1  56589I70788   111.0        1820.0       2221.40   1068.68
# 150         1  24360I70784   634.0        8977.0      21762.43   2056.08
# 188         1  23730I82738   422.0       13601.0      16400.20   1843.27
# 213         1  15835I84453   879.0       45729.5      45729.50   7464.54
# 263         1  87713I95207    94.0        2700.0       2757.79    200.13
# ...       ...          ...     ...           ...           ...       ...
# 209338      1  91067I90848   843.0        6309.0       6694.81   4182.61
# 209344      1  50726I89231   766.0       12550.0      12792.85   1312.93
# 209402      1  72685I89234   873.0        3350.0       3510.21   1504.48
# 209407      1  41650I88659   268.0       10322.0      10322.00   2464.86
# 209581      1  13819I82733  1365.0       18657.0      24825.00   6314.34
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# ...

# %%
#Removing all the data points where the customer has availed no loans in the last 90 days since the points do not help in the scope
data=data[data['cnt_loans90']>0]

# %%
data.shape
# Out:
# (207557, 36)

# %%
data.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
data['month']=data['pdate'].dt.month
data.drop(['pdate'],axis=1,inplace=True)

# %%
data.dtypes
# Out:
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# ...

# %%
data['pcircle'].unique()
# Out:
# array(['UPW'], dtype=object)

# %%
data['msisdn'].nunique()
# Out:
# 184241

# %%
data.drop(['pcircle','msisdn'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (207557, 34)

# %%
data['label'].value_counts()
# Out:
# 1    181395
# 0     26162
# Name: label, dtype: int64

# %%
print(data['aon'].max())
print(data['aon'].min())
# Out:
# 999860.755167902
# -48.0

# %%
data[data.aon < 0]
# Out:
#         label   aon  daily_decr30  daily_decr90  rental30  rental90  \
# 31          1 -42.0      8.864333      8.864333    780.71    780.71
# 198         1 -36.0     32.075333     32.075333   1557.53   1557.53
# 323         1 -37.0      9.160000      9.160000    203.04    203.04
# 505         1 -36.0     11.470333     11.470333     40.04     40.04
# 604         1 -35.0     12.474000     12.474000   1823.08   1823.08
# ...       ...   ...           ...           ...       ...       ...
# 208717      1 -34.0     19.260000     19.260000    714.15    714.15
# 209122      1 -18.0    700.580000    700.600000   1057.72   1090.76
# 209241      1 -28.0     10.640000     10.640000    133.35    133.35
# 209422      1 -44.0      7.166667      7.166667    368.55    368.55
# 209515      0  -2.0   1030.000000   1030.000000    634.91    634.91
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
40*365
# Out:
# 14600

# %%
data[data.aon > 14600]
# Out:
#         label            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 66          1  929670.835962   4130.729333   4151.880000   6139.79   6529.55
# 158         1  860950.168106     19.396000     19.396000     78.12     78.12
# 309         1  697664.842824      4.388000      4.388000   1002.96   1002.96
# 488         1  640022.888780   3302.210667   3315.440000     84.00     90.00
# 582         1  872767.047840    242.000000    242.000000      0.00      0.00
# ...       ...            ...           ...           ...       ...       ...
# 209023      1  504021.842848      3.026667      3.026667    567.36    567.36
# 209156      1  959124.978632  13103.000000  17517.650000  12734.61  17410.82
# 209328      1  803380.621830     18.821333     18.821333     98.24     98.24
# 209440      0  581435.484230      2.666667      2.666667     10.00     10.00
# 209577      1  811881.372822    149.760000    149.760000    922.20    922.20
#
# ...

# %%
# Removing all the datapoints with values less than 0 and greater than 14600 since age cannot be negative and mobiles have been in operation for only 40 years at max
data=data[data['aon']>0]
data=data[data['aon']<14600]

# %%
data.shape
# Out:
# (203955, 34)

# %%
data['label'].value_counts()
# Out:
# 1    178576
# 0     25379
# Name: label, dtype: int64

# %%
data[data.daily_decr30 < 0]
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 75          0   169.0     -2.166667     -2.166667    135.72    135.72
# 79          0   766.0     -0.250000     -0.250000      0.00      0.00
# 97          0   799.0     -0.900000     -0.900000    140.94    140.94
# 110         0   136.0     -0.400000     -0.400000      0.00      0.00
# 274         0   549.0     -0.481667     -0.481667   1153.11   1153.11
# ...       ...     ...           ...           ...       ...       ...
# 209224      1   643.0     -0.825000     -0.825000     45.00     45.00
# 209256      0   882.0     -5.000000     -5.000000  12208.50  12208.50
# 209288      0  1818.0     -0.180000     -0.180000   1127.52   1127.52
# 209427      0  1061.0     -0.331333     -0.331333    426.16    426.16
# 209513      0   112.0     -0.500000     -0.500000      0.00      0.00
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
data=data[data['daily_decr30'] >=0]

# %%
data.shape
# Out:
# (202144, 34)

# %%
data['label'].value_counts()
# Out:
# 1    178299
# 0     23845
# Name: label, dtype: int64

# %%
data['last_rech_date_ma'].max()
# Out:
# 998650.3777327021

# %%
data[data.last_rech_date_ma > 14600]
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 54          1   635.0      5.500000      5.500000     75.90     75.90
# 160         1   415.0   9507.542667   9622.480000    418.58   -239.39
# 234         1   211.0      0.640000      0.640000    227.60    227.60
# 478         1   675.0     36.495000     36.495000    354.75    354.75
# 642         0   538.0   2555.472000   2554.020000   2661.16   9705.56
# ...       ...     ...           ...           ...       ...       ...
# 209058      1  1096.0     76.076000     76.076000    238.55    238.55
# 209375      1  1319.0     56.602333     56.602333    921.69    921.69
# 209467      1   190.0   2601.750000   2622.100000   -334.62   -441.57
# 209502      1   460.0     55.520000     55.520000    877.40    877.40
# 209534      0   168.0     15.400000     15.400000    922.20    922.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
data=data[data['last_rech_date_ma'] < 14600]

# %%
data.shape
# Out:
# (201133, 34)

# %%
data['label'].value_counts()
# Out:
# 1    177397
# 0     23736
# Name: label, dtype: int64

# %%
data=data[data['last_rech_date_da'] < 14600]
data.shape
# Out:
# (200121, 34)

# %%
data['label'].value_counts()
# Out:
# 1    176501
# 0     23620
# Name: label, dtype: int64

# %%
data[data.last_rech_amt_ma < 0]
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, month]
# Index: []

# %%
data[data.cnt_ma_rech30 < 0]
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, month]
# Index: []

# %%
data[data.sumamnt_ma_rech30 < 0]
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, month]
# Index: []

# %%
data[data.cnt_da_rech30 < 0]
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, month]
# Index: []

# %%
data['maxamnt_loans30'].value_counts()
# Out:
# 6.000000        172326
# 12.000000        25597
# 0.000000          1199
# 94938.650685         1
# 75033.890011         1
#                  ...
# 53666.885900         1
# 67319.013426         1
# 36610.121211         1
# 33813.835016         1
# 94789.557413         1
# Name: maxamnt_loans30, Length: 1002, dtype: int64

# %%
data[data.maxamnt_loans30 > 12]
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 119         1  1454.0     19.578667     19.578667    148.88    148.88
# 126         1   811.0    166.796667    166.796667    -44.88    -44.88
# 147         1   198.0  18301.000000  28936.470000   8634.10  11994.34
# 370         1  1737.0     33.000000     33.000000    130.05    130.05
# 375         1   603.0   9970.000000  10770.000000   9343.38  15443.96
# ...       ...     ...           ...           ...       ...       ...
# 209190      1  1211.0  16039.000000  18645.190000   8391.52  11936.73
# 209263      1   904.0     96.906667     96.906667   2516.20   2516.20
# 209332      1  1846.0     55.680000     55.680000   1140.16   1140.16
# 209393      1  1639.0     52.031333     52.031333    957.10    957.10
# 209425      1  1246.0    113.715000    113.715000   2229.66   2229.66
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
#data=data[data['maxamnt_loans30'] < 12]
#data.shape

# %%
data['label'].value_counts()
# Out:
# 1    176501
# 0     23620
# Name: label, dtype: int64

# %%
data[data.payback30 < 0]
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, month]
# Index: []

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True)

# %%
data.drop(['daily_decr30','rental30','cnt_loans30','medianamnt_loans30'],axis=1,inplace=True)

# %%
data
# Out:
#         label     aon  daily_decr90  rental90  last_rech_date_ma  \
# 1           0   272.0   3065.150000    260.13                2.0
# 2           1   712.0  12124.750000   3691.26               20.0
# 3           1   535.0   1398.000000    900.13                3.0
# 4           1   241.0     21.228000    159.42               41.0
# 5           1   947.0    150.619333   1098.90                4.0
# ...       ...     ...           ...       ...                ...
# 209589      1   404.0    151.872333   1089.19                1.0
# 209590      1  1075.0     36.936000   1728.36                4.0
# 209591      1  1013.0  11904.350000   8893.20                3.0
# 209592      1  1732.0  12574.370000    984.58                2.0
# 209593      1  1581.0   4534.820000    631.20               13.0
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 1                     0.0              1539              2          21.0
# ...

# %%
# As per the above box plot, outliers are present in the data, hence removing using zscore
from scipy.stats import zscore
z_sc=np.abs(zscore(data))
print(data.shape)
data=data.loc[(z_sc<3).all(axis=1)]
print(data.shape)
# Out:
# (200121, 30)
# (152922, 30)

# %%
#Graphical Representation
plt.figure(figsize=(12,8))
sns.lineplot(x='aon',y='label',data=data)

# %%
sns.barplot(x=data['label'],y=data['aon'])

# %%
sns.barplot(x=data['month'],y=data['label'])

# %%
sns.barplot(x=data['label'],y=data['last_rech_date_ma'])

# %%
sns.lineplot(x=data['label'],y=data['aon'])

# %%
x=data.iloc[:,1:]
y=data.iloc[:,:1]

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=2)
x_res,y_res=sm.fit_sample(x,y.values.ravel())

# %%
print('After OverSampling, the shape of x: {}'.format(x_res.shape)) 
print('After OverSampling, the shape of y: {} \n'.format(y_res.shape)) 
  
print("After OverSampling, counts of label '1': {}".format(sum(y_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(y_res == 0)))
# Out:
# After OverSampling, the shape of x: (267552, 29)
# After OverSampling, the shape of y: (267552,)
#
# After OverSampling, counts of label '1': 133776
# After OverSampling, counts of label '0': 133776

# %%
x_res
# Out:
#                 aon  daily_decr90     rental90  last_rech_date_ma  \
# 0        272.000000   3065.150000   260.130000           2.000000
# 1        712.000000  12124.750000  3691.260000          20.000000
# 2        535.000000   1398.000000   900.130000           3.000000
# 3        947.000000    150.619333  1098.900000           4.000000
# 4        568.000000   2261.460000   380.130000           2.000000
# ...             ...           ...          ...                ...
# 267547  1048.886607      1.138203    -3.450925           0.000000
# 267548   432.691986   2476.732738  1080.331766           4.557491
# 267549   368.719431      1.007203     0.000000           0.000000
# 267550  1061.802832   3456.780490  8378.964259           5.267517
# 267551   577.684368      7.198924   778.445003           0.000000
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 0                     0.0              1539              2     21.000000
# ...

# %%
y_res
# Out:
# array([0, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
y_res=y_res.reshape(-1,1)

# %%
y_res
# Out:
# array([[0],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
#Scaling the attributes
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_res=sc.fit_transform(x_res)
x_res.shape
# Out:
# (267552, 29)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,random_state=42)

# %%
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (200664, 29) (66888, 29)
# (200664, 1) (66888, 1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,auc,roc_curve

# %%
lr=LogisticRegression()
gnb=GaussianNB()
knc=KNeighborsClassifier(n_neighbors=8)
svc=SVC()
dtc=DecisionTreeClassifier(random_state=6)
rfc=RandomForestClassifier(n_estimators=200,random_state=42)

# %%
models =[]
models.append(('LogisticRegression',lr))
models.append(('GaussianNB',gnb))
models.append(('DecisionTreeClassifier',dtc))
models.append(('RandomForestClassifier',rfc))
models.append(('KNeighborsClassifer',knc))
#models.append(('SVC',svc))

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print('**************',name,'***********')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pred)
    score.append(AS*100)
    print('Accuracy Score =',AS)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross Val Score =',sc)
    cvs.append(sc*100)
    false_positive_rate,true_positive_rate,thresholds = roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print('roc-auc score =',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('Classification Report\n',classification_report(y_test,pred))
    print('\n')
    print('Confusion Matrix \n',confusion_matrix(y_test,pred))
# Out:
# ************** LogisticRegression ***********
#
#
# LogisticRegression()
#
#
# Accuracy Score = 0.7858061236694175
#
#
# Cross Val Score = 0.8757471195783866
# roc-auc score = 0.785655605272569
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79     33635
#            1       0.80      0.76      0.78     33253
#
#     accuracy                           0.79     66888
#    macro avg       0.79      0.79      0.79     66888
# weighted avg       0.79      0.79      0.79     66888
#
#
#
# Confusion Matrix
#  [[27312  6323]
#  [ 8004 25249]]
# ************** GaussianNB ***********
#
#
# GaussianNB()
#
#
# Accuracy Score = 0.7296226527927281
#
#
# Cross Val Score = 0.6544186271412097
# roc-auc score = 0.7288726075121257
#
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.68      0.86      0.76     33635
# ...

# %%
f_result=pd.DataFrame({'Model' : Model, 'Accuracy Score': score,'Cross_Val_Score':cvs,'ROC-AUC_Curve':rocscore})
f_result
# Out:
#                     Model  Accuracy Score  Cross_Val_Score  ROC-AUC_Curve
# 0      LogisticRegression       78.580612        87.574712      78.565561
# 1              GaussianNB       72.962265        65.441863      72.887261
# 2  DecisionTreeClassifier       90.292728        86.749456      90.287485
# 3  RandomForestClassifier       94.127497        91.353761      94.131796
# 4     KNeighborsClassifer       84.808934        88.021344      84.753716

# %%
# Random Forest classifier is the best model and hence we use that, now let's try if we can further enhance the performance using hyperparameter tuning

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

# %%
from sklearn.model_selection import GridSearchCV
rfc=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rfc,param_grid=param_grid,cv=3)
grid_search.fit(x_train,y_train)

# %%
grid_search.best_params_

# %%
from sklearn.externals import joblib
joblib.dump(rfc,'Micro_Credit_Defaulter_Prediction.pkl')
